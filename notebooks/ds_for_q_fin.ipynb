# %% [markdown]
# https://www.kaggle.com/code/lusfernandotorres/data-science-for-financial-markets

# %%
# !pip install yfinance

# %%
# !pip install quantstats
# Out:
# Requirement already satisfied: quantstats in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (0.0.76)
# Requirement already satisfied: pandas<3.0.0,>=1.5.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (2.3.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (2.3.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (0.13.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (3.10.6)
# Requirement already satisfied: scipy>=1.7.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (1.16.1)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.2.65 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (0.2.65)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (2.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from quantstats) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from matplotlib>=3.3.0->quantstats) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from matplotlib>=3.3.0->quantstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from matplotlib>=3.3.0->quantstats) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from matplotlib>=3.3.0->quantstats) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from matplotlib>=3.3.0->quantstats) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from matplotlib>=3.3.0->quantstats) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.0->quantstats) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.0->quantstats) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from python-dateutil>=2.8.0->quantstats) (1.16.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (6.32.0)
# Requirement already satisfied: websockets>=13.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from yfinance>=0.2.65->quantstats) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.65->quantstats) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.65->quantstats) (4.12.2)
# Requirement already satisfied: cffi>=1.12.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from requests>=2.31->yfinance>=0.2.65->quantstats) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from requests>=2.31->yfinance>=0.2.65->quantstats) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from requests>=2.31->yfinance>=0.2.65->quantstats) (2.4.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (2.22)

# %%
# !pip install pyportfolioopt
# Out:
# Collecting pyportfolioopt
#   Downloading pyportfolioopt-1.5.6-py3-none-any.whl.metadata (22 kB)
# Collecting cvxpy>=1.1.19 (from pyportfolioopt)
#   Downloading cvxpy-1.7.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (9.5 kB)
# Collecting ecos<3.0.0,>=2.0.14 (from pyportfolioopt)
#   Downloading ecos-2.0.14.tar.gz (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 1.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pyportfolioopt) (2.3.2)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pyportfolioopt) (2.3.2)
# Collecting plotly<6.0.0,>=5.0.0 (from pyportfolioopt)
#   Using cached plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.3 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pyportfolioopt) (1.16.1)
# Collecting osqp>=0.6.2 (from cvxpy>=1.1.19->pyportfolioopt)
#   Downloading osqp-1.0.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting clarabel>=0.5.0 (from cvxpy>=1.1.19->pyportfolioopt)
#   Downloading clarabel-0.11.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy>=1.1.19->pyportfolioopt)
#   Downloading scs-3.2.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas>=0.19->pyportfolioopt) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas>=0.19->pyportfolioopt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas>=0.19->pyportfolioopt) (2025.2)
# Collecting tenacity>=6.2.0 (from plotly<6.0.0,>=5.0.0->pyportfolioopt)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt) (24.1)
# Requirement already satisfied: cffi in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->pyportfolioopt) (1.17.1)
# Collecting jinja2 (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (69.5.1)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (1.5.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyportfolioopt) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->pyportfolioopt) (2.22)
# Collecting MarkupSafe>=2.0 (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Downloading pyportfolioopt-1.5.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 439.3 kB/s eta 0:00:000:00:01
# Downloading cvxpy-1.7.2-cp311-cp311-macosx_10_9_universal2.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.6 MB/s eta 0:00:00a 0:00:01
# Using cached plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Downloading clarabel-0.11.1-cp39-abi3-macosx_11_0_arm64.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.1/935.1 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Downloading osqp-1.0.4-cp311-cp311-macosx_11_0_arm64.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.7/291.7 kB 1.4 MB/s eta 0:00:0000:0100:01
# Downloading scs-3.2.8-cp311-cp311-macosx_11_0_arm64.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 74.7 kB/s eta 0:00:00a 0:00:01
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Building wheels for collected packages: ecos
#   Building wheel for ecos (pyproject.toml) ... done
#   Created wheel for ecos: filename=ecos-2.0.14-cp311-cp311-macosx_11_0_arm64.whl size=72759 sha256=34c168268e85241b19f18ca6ef954117b4a5ec2ae573d697895aac4219b916a0
#   Stored in directory: /Users/roman/Library/Caches/pip/wheels/8d/2c/50/ee2c49471cb896af40a1109297f6d62ff1296e446f8c59c67c
# Successfully built ecos
# Installing collected packages: tenacity, MarkupSafe, scs, plotly, jinja2, ecos, clarabel, osqp, cvxpy, pyportfolioopt
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.3.0
#     Uninstalling plotly-6.3.0:
#       Successfully uninstalled plotly-6.3.0
# Successfully installed MarkupSafe-3.0.2 clarabel-0.11.1 cvxpy-1.7.2 ecos-2.0.14 jinja2-3.1.6 osqp-1.0.4 plotly-5.24.1 pyportfolioopt-1.5.6 scs-3.2.8 tenacity-9.1.2

# %%
# !pip install ta
# Out:
# Requirement already satisfied: ta in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (0.11.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from ta) (2.3.2)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from ta) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas->ta) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)

# %%
pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting lxml (from pandas_datareader)
#   Downloading lxml-6.0.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: pandas>=0.23 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas_datareader) (2.3.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas_datareader) (2.32.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/algo_train/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.16.0)
# Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Downloading lxml-6.0.1-cp311-cp311-macosx_10_9_universal2.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 540.8 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: lxml, pandas_datareader
# Successfully installed lxml-6.0.1 pandas_datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Data handling and statistical analysis 
import pandas as pd
from pandas_datareader import data
import numpy as np
from scipy import stats

# Data visualization 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Optimization and allocation
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import black_litterman, BlackLittermanModel

# Financial data 
import quantstats as qs
import ta
import yfinance as yf

# Linear Regression Model
from sklearn.linear_model import LinearRegression

# Enabling Plotly offline
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

# Datetime and hiding warnings 
import datetime as dt
import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Daily Returns

# %%
# Getting daily returns for 4 different US stocks in the same time window
aapl = qs.utils.download_returns('AAPL')
aapl = aapl.loc['2010-07-01':'2023-02-10']

tsla = qs.utils.download_returns('TSLA')
tsla = tsla.loc['2010-07-01':'2023-02-10']

dis = qs.utils.download_returns('DIS')
dis = dis.loc['2010-07-01':'2023-02-10']

amd = qs.utils.download_returns('AMD')
amd = amd.loc['2010-07-01':'2023-02-10']
# Out:
# Failed to get ticker 'DIS' reason: Failed to perform, curl: (28) Connection timed out after 10001 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.

# %%
# Converting timezone
aapl.index = aapl.index.tz_localize('utc')
tsla.index = tsla.index.tz_localize('utc')
dis.index = dis.index.tz_localize('utc')
amd.index = amd.index.tz_localize('utc')

# %%
# Plotting Daily Returns for each stock
print('\n')
print('\nApple Daily Returns Plot:\n')
qs.plots.daily_returns(aapl)
print('\n')
print('\n')
print('\nTesla Inc. Daily Returns Plot:\n')
qs.plots.daily_returns(tsla)
print('\n')
print('\n')
print('\nThe Walt Disney Company Daily Returns Plot:\n')
qs.plots.daily_returns(dis)
print('\n')
print('\n')
print('\nAdvances Micro Devices, Inc. Daily Returns Plot:\n')
qs.plots.daily_returns(amd)
